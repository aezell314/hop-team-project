# %%
from sqlalchemy import create_engine, text
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create engine
db_name = 'hop_team'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{db_name}"

engine = create_engine(connection_string)

# %%
# Read hop_team_nashville_mv
query = '''
    SELECT *
    FROM hop_team_nashville_mv;
'''

with engine.connect() as connection:
    hop_team_nashville_df = pd.read_sql(text(query), con=connection)

hop_team_nashville_df.head(2)
# Out:
#    referring_pcp_npi             pcp                         pcp_grouping  \
# 0         1962515023    BELINDA BART  Allopathic & Osteopathic Physicians
# 1         1467428680  RICHARD POWERS  Allopathic & Osteopathic Physicians
#
#   pcp_classification pcp_specialization  receiving_hospital_npi  \
# 0    Family Medicine               None              1891000923
# 1    Family Medicine               None              1891000923
#
#                                         hospital hospital_grouping  \
# 0  BEHAVIORAL HEALTHCARE CENTER AT COLUMBIA, LLC         Hospitals
# 1  BEHAVIORAL HEALTHCARE CENTER AT COLUMBIA, LLC         Hospitals
#
#   hospital_classification hospital_specialization  patient_count  \
# 0    Psychiatric Hospital                    None            132
# 1    Psychiatric Hospital                    None            125
#
#    transaction_count  average_day_wait  std_day_wait
# 0                190             0.832         8.515
# 1                196             0.153         1.819

# %%
# Read hop_team community info
hop_team_community_df = pd.read_csv('../data/hop_team_community.csv')
hop_team_community_df.head(2)
# Out:
#           npi  communityId
# 0  1003013160         1423
# 1  1003050972         1438

# %%
# Merge hop_team_nashville with hop_team_community
hop_team_nashville_community_df = (
    hop_team_nashville_df
        .merge(
            hop_team_community_df,
            left_on='referring_pcp_npi',
            right_on='npi',
            how='left'
        )
)
hop_team_nashville_community_df.head(2)
# Out:
#    referring_pcp_npi             pcp                         pcp_grouping  \
# 0         1962515023    BELINDA BART  Allopathic & Osteopathic Physicians
# 1         1467428680  RICHARD POWERS  Allopathic & Osteopathic Physicians
#
#   pcp_classification pcp_specialization  receiving_hospital_npi  \
# 0    Family Medicine               None              1891000923
# 1    Family Medicine               None              1891000923
#
#                                         hospital hospital_grouping  \
# 0  BEHAVIORAL HEALTHCARE CENTER AT COLUMBIA, LLC         Hospitals
# 1  BEHAVIORAL HEALTHCARE CENTER AT COLUMBIA, LLC         Hospitals
#
#   hospital_classification hospital_specialization  patient_count  \
# 0    Psychiatric Hospital                    None            132
# 1    Psychiatric Hospital                    None            125
#
#    transaction_count  average_day_wait  std_day_wait         npi  communityId
# 0                190             0.832         8.515  1962515023         1407
# 1                196             0.153         1.819  1467428680         1407

# %% [markdown]
# ## Get top 10 hospitals by referral count

# %%
hospital_referrals_count = (
    hop_team_nashville_df
        .groupby('hospital')
        .agg(
            referrals=('transaction_count', 'sum')
        )
)
hospital_referrals_count
# Out:
#                                                     referrals
# hospital
# BEHAVIORAL HEALTHCARE CENTER AT COLUMBIA, LLC             581
# CENTRAL TENNESSEE HOSPITAL CORPORATION                  17984
# CURAHEALTH NASHVILLE, LLC                                 602
# ENCOMPASS HEALTH REHABILITATION HOSPITAL OF FRA...        629
# HCA HEALTH SERVICES OF TENNESSEE, INC.                 188805
# HENDERSONVILLE HOSPITAL CORPORATION                     30330
# HTI MEMORIAL HOSPITAL CORPORATION                       39700
# MACON COUNTY GENERAL HOSPITAL, INC.                      8787
# MACON HOSPITAL, INC.                                       61
# MAURY REGIONAL HOSPITAL                                 82010
# MAURY REGIONAL HOSPITAL MARSHALL MEDICAL CENTER          7115
# NASHVILLE GENERAL HOSPITAL                               3462
# NORTHCREST MEDICAL CENTER                               16052
# RIVER PARK HOSPITAL LLC                                   171
# RIVERVIEW MEDICAL CENTER LLC                             6520
# RIVERVIEW MEDICAL CENTER, LLC                              82
# ROLLING HILLS HOSPITAL LLC                                443
# SAINT THOMAS DEKALB HOSPITAL, LLC                        3509
# SAINT THOMAS RIVER PARK HOSPITAL, LLC                   19673
# SAINT THOMAS RUTHERFORD HOSPITAL                        51123
# SAINT THOMAS STONES RIVER HOSPITAL, LLC                  1404
# SAINT THOMAS WEST HOSPITAL                             137648
# SELECT SPECIALTY HOSPITAL - NASHVILLE LLC                4397
# SETON CORPORATION                                         338
# SHELBYVILLE HOSPITAL COMPANY LLC                         7019
# SMITH COUNTY MEMORIAL HOSPITAL LLC                         56
# SRHS HOLDINGS LLC                                         273
# SUMNER REGIONAL HEALTH SYSTEMS, INC                      2517
# SUMNER REGIONAL MEDICAL CENTER LLC                      42256
# TCMC MADISON-PORTLAND, INC.                               405
# TROUSDALE MEDICAL CENTER LLC                             1716
# TRUSTPOINT HOSPITAL, LLC                                  317
# VANDERBILT STALLWORTH REHABILITATION HOSPITAL LP          702
# VANDERBILT UNIVERSITY MEDICAL CENTER                   283171
# WILLIAMSON COUNTY HOSPITAL DISTRICT                     41407

# %%
top_10_hospitals_referred_to = (
    hospital_referrals_count[hospital_referrals_count['referrals'] >= 10000]
    .sort_values('referrals', ascending=False)
    .head(10)
    .index
    .to_list()
)
top_10_hospitals_referred_to
# Out:
# ['VANDERBILT UNIVERSITY MEDICAL CENTER',
#  'HCA HEALTH SERVICES OF TENNESSEE, INC.',
#  'SAINT THOMAS WEST HOSPITAL',
#  'MAURY REGIONAL HOSPITAL',
#  'SAINT THOMAS RUTHERFORD HOSPITAL',
#  'SUMNER REGIONAL MEDICAL CENTER LLC',
#  'WILLIAMSON COUNTY HOSPITAL DISTRICT',
#  'HTI MEMORIAL HOSPITAL CORPORATION',
#  'HENDERSONVILLE HOSPITAL CORPORATION',
#  'SAINT THOMAS RIVER PARK HOSPITAL, LLC']

# %% [markdown]
# ## Get top 10 pcp specialties by referral count

# %%
specialty_referrals_count = (
    hop_team_nashville_df
        .groupby('pcp_specialization')
        .agg(
            referrals=('transaction_count', 'sum')
        )
)
specialty_referrals_count
# Out:
#                                                   referrals
# pcp_specialization
# Addiction Medicine                                      183
# Adult Congenital Heart Disease                          109
# Adult Medicine                                         1341
# Advanced Heart Failure and Transplant Cardiology      15903
# Cardiovascular Disease                               200430
# Clinical Cardiac Electrophysiology                    27522
# Critical Care Medicine                                 4690
# Endocrinology, Diabetes & Metabolism                  16912
# Gastroenterology                                      39056
# Geriatric Medicine                                     8449
# Hematology                                             4055
# Hematology & Oncology                                 48313
# Hepatology                                              296
# Hospice and Palliative Medicine                        2334
# Hypertension Specialist                                 873
# Infectious Disease                                    15764
# Interventional Cardiology                             34248
# Medical Oncology                                      33073
# Nephrology                                            69057
# Obesity Medicine                                        326
# Pediatric Cardiology                                    200
# Pediatric Critical Care Medicine                        570
# Pediatric Nephrology                                    104
# Pulmonary Disease                                     66891
# Rheumatology                                          17481
# Sleep Medicine                                         2194
# Sports Medicine                                        4118
# Transplant Hepatology                                  1257

# %%
top_10_specialty_referred_from = (
    specialty_referrals_count[specialty_referrals_count['referrals'] >= 10000]
    .sort_values('referrals', ascending=False)
    .head(10)
    .index
    .to_list()
)
top_10_specialty_referred_from
# Out:
# ['Cardiovascular Disease',
#  'Nephrology',
#  'Pulmonary Disease',
#  'Hematology & Oncology',
#  'Gastroenterology',
#  'Interventional Cardiology',
#  'Medical Oncology',
#  'Clinical Cardiac Electrophysiology',
#  'Rheumatology',
#  'Endocrinology, Diabetes & Metabolism']

# %%
top_10_referral_df = (
    hop_team_nashville_df[
        hop_team_nashville_df['hospital'].isin(top_10_hospitals_referred_to) &
        hop_team_nashville_df['pcp_specialization'].isin(top_10_specialty_referred_from)]
)
top_10_referral_df
# Out:
#       referring_pcp_npi              pcp                         pcp_grouping  \
# 58           1962497867   ABU FAKHRUDDIN  Allopathic & Osteopathic Physicians
# 59           1962497867   ABU FAKHRUDDIN  Allopathic & Osteopathic Physicians
# 63           1871756080   ALYSSA SAELENS  Allopathic & Osteopathic Physicians
# 64           1861668907    AMANDA DANIEL  Allopathic & Osteopathic Physicians
# 69           1275793283   ANDREW GOODMAN  Allopathic & Osteopathic Physicians
# ...                 ...              ...                                  ...
# 2777         1386663144  THOMAS THOMPSON  Allopathic & Osteopathic Physicians
# 2779         1720282205    WALEED KHALAF  Allopathic & Osteopathic Physicians
# 2780         1093818981     WALTER CLAIR  Allopathic & Osteopathic Physicians
# 2782         1952304990    WILLIAM FLEET  Allopathic & Osteopathic Physicians
# 2784         1861430621      WILSON KEMP  Allopathic & Osteopathic Physicians
#
#      pcp_classification                    pcp_specialization  \
# 58    Internal Medicine                      Gastroenterology
# 59    Internal Medicine                      Gastroenterology
# 63    Internal Medicine                     Pulmonary Disease
# 64    Internal Medicine  Endocrinology, Diabetes & Metabolism
# 69    Internal Medicine             Interventional Cardiology
# ...                 ...                                   ...
# 2777  Internal Medicine                Cardiovascular Disease
# 2779  Internal Medicine                 Hematology & Oncology
# 2780  Internal Medicine                Cardiovascular Disease
# 2782  Internal Medicine                Cardiovascular Disease
# 2784  Internal Medicine                Cardiovascular Disease
#
#       receiving_hospital_npi                                hospital  \
# 58                1023055126  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 59                1932146032  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 63                1023055126  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 64                1023055126  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 69                1932146032  HCA HEALTH SERVICES OF TENNESSEE, INC.
# ...                      ...                                     ...
# 2777              1265445506     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 2779              1265445506     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 2780              1265445506     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 2782              1265445506     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 2784              1265445506     WILLIAMSON COUNTY HOSPITAL DISTRICT
#
#      hospital_grouping      hospital_classification hospital_specialization  \
# 58           Hospitals  General Acute Care Hospital                    None
# 59           Hospitals  General Acute Care Hospital                    None
# 63           Hospitals  General Acute Care Hospital                    None
# 64           Hospitals  General Acute Care Hospital                    None
# 69           Hospitals  General Acute Care Hospital                    None
# ...                ...                          ...                     ...
# 2777         Hospitals  General Acute Care Hospital                    None
# 2779         Hospitals  General Acute Care Hospital                    None
# 2780         Hospitals  General Acute Care Hospital                    None
# 2782         Hospitals  General Acute Care Hospital                    None
# 2784         Hospitals  General Acute Care Hospital                    None
#
#       patient_count  transaction_count  average_day_wait  std_day_wait
# 58              540                948             2.794        16.876
# 59               51                 53            29.245        57.811
# 63               37                 61             0.115         0.486
# 64              231                566             6.652        27.725
# 69               51                 74             9.500        30.054
# ...             ...                ...               ...           ...
# 2777            717                946            15.223        41.357
# 2779             66                 97            15.206        30.333
# 2780             40                 74            35.527        48.210
# 2782            932               1300            15.931        41.599
# 2784            109                175            33.251        56.694
#
# [1064 rows x 14 columns]

# %%
top_10_referral_df_pivot = pd.pivot_table(
    top_10_referral_df,
    values='transaction_count',
    index='hospital', 
    columns='pcp_specialization', 
    aggfunc='sum'
)
top_10_referral_df_pivot
# Out:
# pcp_specialization                      Cardiovascular Disease  \
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.                 26617.0
# HENDERSONVILLE HOSPITAL CORPORATION                     9667.0
# HTI MEMORIAL HOSPITAL CORPORATION                       6625.0
# MAURY REGIONAL HOSPITAL                                 7323.0
# SAINT THOMAS RIVER PARK HOSPITAL, LLC                   1983.0
# SAINT THOMAS RUTHERFORD HOSPITAL                        7664.0
# SAINT THOMAS WEST HOSPITAL                             30206.0
# SUMNER REGIONAL MEDICAL CENTER LLC                      8783.0
# VANDERBILT UNIVERSITY MEDICAL CENTER                   72422.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT                    13919.0
#
# pcp_specialization                      Clinical Cardiac Electrophysiology  \
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.                              4688.0
# HENDERSONVILLE HOSPITAL CORPORATION                                  347.0
# HTI MEMORIAL HOSPITAL CORPORATION                                   3420.0
# MAURY REGIONAL HOSPITAL                                              648.0
# SAINT THOMAS RIVER PARK HOSPITAL, LLC                               1081.0
# SAINT THOMAS RUTHERFORD HOSPITAL                                    1353.0
# SAINT THOMAS WEST HOSPITAL                                          7369.0
# SUMNER REGIONAL MEDICAL CENTER LLC                                   294.0
# VANDERBILT UNIVERSITY MEDICAL CENTER                                6783.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT                                 1005.0
#
# pcp_specialization                      Endocrinology, Diabetes & Metabolism  \
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                3294.0
# HENDERSONVILLE HOSPITAL CORPORATION                                    367.0
# HTI MEMORIAL HOSPITAL CORPORATION                                        NaN
# MAURY REGIONAL HOSPITAL                                                  NaN
# SAINT THOMAS RIVER PARK HOSPITAL, LLC                                    NaN
# SAINT THOMAS RUTHERFORD HOSPITAL                                       989.0
# SAINT THOMAS WEST HOSPITAL                                            3068.0
# SUMNER REGIONAL MEDICAL CENTER LLC                                     496.0
# VANDERBILT UNIVERSITY MEDICAL CENTER                                  8084.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT                                    212.0
#
# pcp_specialization                      Gastroenterology  \
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.            8334.0
# HENDERSONVILLE HOSPITAL CORPORATION               2018.0
# HTI MEMORIAL HOSPITAL CORPORATION                 1652.0
# MAURY REGIONAL HOSPITAL                           6070.0
# SAINT THOMAS RIVER PARK HOSPITAL, LLC              142.0
# SAINT THOMAS RUTHERFORD HOSPITAL                  1297.0
# SAINT THOMAS WEST HOSPITAL                        5435.0
# SUMNER REGIONAL MEDICAL CENTER LLC                2077.0
# VANDERBILT UNIVERSITY MEDICAL CENTER             10000.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT                937.0
#
# pcp_specialization                      Hematology & Oncology  \
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.                 7747.0
# HENDERSONVILLE HOSPITAL CORPORATION                     595.0
# HTI MEMORIAL HOSPITAL CORPORATION                      1021.0
# MAURY REGIONAL HOSPITAL                                2015.0
# SAINT THOMAS RIVER PARK HOSPITAL, LLC                   543.0
# SAINT THOMAS RUTHERFORD HOSPITAL                       1918.0
# SAINT THOMAS WEST HOSPITAL                             4823.0
# SUMNER REGIONAL MEDICAL CENTER LLC                      673.0
# VANDERBILT UNIVERSITY MEDICAL CENTER                  25227.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT                     652.0
#
# pcp_specialization                      Interventional Cardiology  \
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.                    18164.0
# HENDERSONVILLE HOSPITAL CORPORATION                        1512.0
# HTI MEMORIAL HOSPITAL CORPORATION                          1332.0
# MAURY REGIONAL HOSPITAL                                    2756.0
# SAINT THOMAS RIVER PARK HOSPITAL, LLC                       352.0
# SAINT THOMAS RUTHERFORD HOSPITAL                           1326.0
# SAINT THOMAS WEST HOSPITAL                                 3320.0
# SUMNER REGIONAL MEDICAL CENTER LLC                          809.0
# VANDERBILT UNIVERSITY MEDICAL CENTER                       2807.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT                         269.0
#
# pcp_specialization                      Medical Oncology  Nephrology  \
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.            4148.0     14180.0
# HENDERSONVILLE HOSPITAL CORPORATION                498.0      1915.0
# HTI MEMORIAL HOSPITAL CORPORATION                  543.0      3129.0
# MAURY REGIONAL HOSPITAL                           4997.0      5166.0
# SAINT THOMAS RIVER PARK HOSPITAL, LLC              674.0       132.0
# SAINT THOMAS RUTHERFORD HOSPITAL                  1810.0      3511.0
# SAINT THOMAS WEST HOSPITAL                        2338.0     11443.0
# SUMNER REGIONAL MEDICAL CENTER LLC                1614.0      3026.0
# VANDERBILT UNIVERSITY MEDICAL CENTER             13001.0     16976.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT               2186.0      2252.0
#
# pcp_specialization                      Pulmonary Disease  Rheumatology
# hospital
# HCA HEALTH SERVICES OF TENNESSEE, INC.            16620.0         951.0
# HENDERSONVILLE HOSPITAL CORPORATION                 655.0         292.0
# HTI MEMORIAL HOSPITAL CORPORATION                  6581.0          89.0
# MAURY REGIONAL HOSPITAL                            3113.0        1469.0
# SAINT THOMAS RIVER PARK HOSPITAL, LLC               549.0           NaN
# SAINT THOMAS RUTHERFORD HOSPITAL                   2644.0         177.0
# SAINT THOMAS WEST HOSPITAL                        12825.0        1065.0
# SUMNER REGIONAL MEDICAL CENTER LLC                 4304.0         483.0
# VANDERBILT UNIVERSITY MEDICAL CENTER              10417.0       12102.0
# WILLIAMSON COUNTY HOSPITAL DISTRICT                2160.0         337.0

# %%
top_10_referral_df_pivot_heatmap = sns.heatmap(
    top_10_referral_df_pivot,
    cmap='crest',
    linewidths=0.5,
    annot=False
)
top_10_referral_df_pivot_heatmap
# Out:
# <Axes: xlabel='pcp_specialization', ylabel='hospital'>

# %%
(
    top_10_referral_df_pivot_heatmap
        .get_figure()
        .savefig(
            fname='../figures/specialization_hospital_referral_heatmap.png',
            dpi=300
        )
)
